# %% [markdown]
# # USPEX SXD point-source reduction example
#
# Last updated 6 March 2023
#
# This notebook demonstrates the reduction of a SXD point-source data using the test data provided with the code
#
#
# ## Steps:
# * setup instrument parameters
# * reduce calibration data
# * extract science point source
# * extract telluric standard point source
# * combine individual science spectra into one spectrum (TBD)
# * combine individual telluric spectra into one spectrum (TBD)
# * telluric calibration science spectrum (TBD)
# * stitch orders for SXD data (TBD)

# %%
# initial imports and setup
import pyspextool as ps
import os

# what instrument and mode we are using
instrument = 'uspex'
mode = 'SXD'

# point to test data folder for USPEX SXD data
# NOTE: this should be moved internally
pfolder = os.path.dirname(os.path.abspath(ps.__file__))+'/../../'
tdfolder = pfolder+'/test_data/{}-{}/'.format(instrument,mode)

# set output pathways
redux_folder = '/Users/adam/projects/spex_archive/test_uspex-SXD/'
raw_path = tdfolder
cal_path = redux_folder+'/cals/'
proc_path = redux_folder+'/proc/'
qa_path = redux_folder+'/cals/'

# file prefixes
src_prefix = 'spc-'
flat_prefix = 'flat-'
arc_prefix = 'arc-'

# file numbers
flat_files = '21-25'
arc_files = '26'
src_files = '1-8'
tell_files = '11-18'

# extraction details
orders = '3-9' # orders to extract
source_type = 'ps' # source type: 'ps' (default) or 'xs'
reduction_mode = 'A-B' # reduction mode: 'A-B' (default), 'A', 'A-Sky/Dark'
npos = 2
aperture_positions = [3.7, 11.2] # preset aperture positions
aperture_method = 'auto' # method to identify aperture: 'fixed', 'guess', or 'auto' (default)
ps_aperture = 1.5 # preset aperture width for point source in multiples of PSF radius
psf_radius = 1.5 # point source PSF radius
ps_bg_parameters = [2.5,4] # point source background parameters; radius to start, then width

# set up instrument
ps.pyspextool_setup(instrument,raw_path=raw_path, cal_path=cal_path, proc_path=proc_path, qa_path=qa_path,verbose=True)
# Out:
# Pyspextool Setup
# ----------------
# Instrument:  uspex
#
# Rawpath:  /Users/adam/python_codes/pyspextool/test_data/uspex-SXD
# Calpath:  /Users/adam/projects/spex_archive/test_uspex-SXD/cals
# Procpath:  /Users/adam/projects/spex_archive/test_uspex-SXD/proc
# Qapath:  /Users/adam/projects/spex_archive/test_uspex-SXD/cals
#
# QA Extension: .pdf

# %%
# conduct calibrations
ps.extract.make_flat(flat_files,'flat{}'.format(flat_files),prefix=flat_prefix,qaplot=False,qafile=True,verbose=True)

ps.extract.make_wavecal(arc_files,'flat{}.fits'.format(flat_files),'wavecal{}'.format(arc_files),\
    prefix=arc_prefix,qafile_findlines=True,use_stored_solution=False,verbose=True)
# Out:
# Make Wavecal File
# -----------------
# Loading FITS images...
# Extracting 1 apertures in 7 orders (without background subtraction)...
# 100% |**********************************************************************|
# Finding the lines...
#  87% |*************************************************************         |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Determining the wavelength solution...
# Writing wavecal to disk...
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# Wavecal wavecal26.fits written to disk.

# %%
# extract first two images of science target

# load in images and apply flat and wavecal calbrations
ps.extract.load_image([src_prefix,ps.io.files.extract_filestring(src_files,method='index')[:2]],\
                      'flat{}.fits'.format(flat_files), 'wavecal{}.fits'.format(arc_files),\
                      flat_field=True, linearity_correction=True,reduction_mode=reduction_mode, \
                      qaplot=False, qafile=True, verbose=True)

# set extraction method to point source
ps.extract.set_extraction_type(source_type)

# make spatial profiles
ps.extract.make_spatial_profiles(qaplot=False, qafile=True, verbose=True)

# identify aperture positions (set above)
if aperture_method=='auto': # this works for method = 'auto'
    ps.extract.locate_aperture_positions(2, method=aperture_method, qaplot=False, qafile=True, verbose=True)
else:
    ps.extract.locate_aperture_positions(aperture_positions, method=aperture_method, qaplot=False, qafile=True, verbose=True)

# select orders to extract (set above)
ps.extract.select_orders(include=orders, qaplot=False, qafile=True, verbose=True)

# trace apertures
ps.extract.trace_apertures(qaplot=False, qafile=True, verbose=True)

# define the aperture - psf, width, background
ps.extract.define_aperture_parameters(ps_aperture, psf_radius=psf_radius,bg_radius=ps_bg_parameters[0],\
                        bg_width=ps_bg_parameters[1], qaplot=False, qafile=True) #, verbose=True

# extract away
ps.extract.extract_apertures(verbose=True)
# Out:
# Loading the flat...
# Loading the wavecal...
# Loading spc-00001.a.fits, spc-00002.b.fits and correcting for non-linearity...
# Flat fielding the image...
# Setting extraction type to point source...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (+, -)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00001.fits to disk.
# Wrote spectra00002.fits to disk.

# %%
# conduct extraction of all remaining files
# NOTE: this is redundant for the first two files

ps.extract.do_all_steps([src_prefix,src_files])
# Out:
# Loading spc-00001.a.fits, spc-00002.b.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (+, -)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00001.fits to disk.
# Wrote spectra00002.fits to disk.
#
# Loading spc-00003.b.fits, spc-00004.a.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (-, +)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00003.fits to disk.
# Wrote spectra00004.fits to disk.
#
# Loading spc-00005.a.fits, spc-00006.b.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (+, -)...
# Updating order selection...
# Tracing apertures...
#  29% |********************                                                  |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00005.fits to disk.
# Wrote spectra00006.fits to disk.
#
# Loading spc-00007.b.fits, spc-00008.a.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (-, +)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00007.fits to disk.
# Wrote spectra00008.fits to disk.

# %%
# Checking output

# Temporary function to read in output spectraN.fits file
# data format is [# apertures x # orders, wave/flx/unc/back, column]
# returns wave, flux, unc, flags

import numpy
import matplotlib.pyplot as plt
from astropy.io import fits
# %matplotlib inline

def tmp_read_file(file,order,mode='A-B'):
    hdu = fits.open(file)
    data = hdu[0].data
    header = hdu[0].header # return this?
    hdu.close()
    orders = header['ORDERS'].split(',')
    orders = [int(x) for x in orders]
    if order > numpy.nanmax(orders) or order < numpy.nanmin(orders):
        raise ValueError('Input order {} is not in range of obtained orders {}'.format(order,orders))
    if mode=='A-B' or mode=='A':
        iref = orders.index(order)
        wave = data[iref,0,:]
        flux = data[iref,1,:]
        unc = data[iref,2,:]
        flags = data[iref,3,:]
    else:
        raise ValueError('cannot yet read in mode {}'.format(mode))
    return wave, flux, unc, flags

def plot_one_order(file,order,mode='A-B'):
    w,f,u,fl = tmp_read_file(file,order,mode=mode)
    fig = plt.figure(figsize=[12,4])
    ax1 = plt.subplot(121)
    ax1.plot(w,f)
    ax1.plot(w,u)
    ax1.set_ylim([-1.,1.2]*numpy.nanquantile(f,[0.05,0.95]))
    ax1.set_xlabel('Wavelength (micron)')
    ax1.set_ylabel('Integrated counts')
    ax2 = plt.subplot(122)
    ax2.plot(w,f/u)
    ax2.set_ylim([-1.,1.2]*numpy.nanquantile(f/u,[0.05,0.95]))
    ax2.set_xlabel('Wavelength (micron)')
    ax2.set_ylabel('S/N')
    plt.tight_layout()
    plt.show()

# def plot_all_orders(file,mode='A-B'):
#     hdu = fits.open(file)
#     data = hdu[0].data
#     header = hdu[0].header # return this?
#     hdu.close()
#     orders = header['ORDERS'].split(',')
#     orders = [int(x) for x in orders]
#     fig = plt.figure(figsize=[8,4*len(orders)])
#     ax = numpy.zeros(2*len(orders))
#     for i,ordr in enumerate(orders):
#         print(i)
#         w = data[i,0,:]
#         f = data[i,1,:]
#         u = data[i,2,:]
#         ax[2*i]= plt.subplot(2,int(len(orders)),int(2*i+1))
#         ax[2*i].plot(w,f)
#         ax[2*i].plot(w,u)
#         ax[2*i].set_ylim([-1.,1.2]*numpy.nanquantile(f,[0.05,0.95]))
#         ax[2*i].set_xlabel('Wavelength (micron)')
#         ax[2*i].set_ylabel('Integrated counts')
#         ax[2*i+1] = plt.subplot(2,int(len(orders)),int(2*i+2))
#         ax[2*i+1].plot(w,f/u)
#         ax[2*i+1].set_ylim([-1.,1.2]*numpy.nanquantile(f/u,[0.05,0.95]))
#         ax[2*i+1].set_xlabel('Wavelength (micron)')
#         ax[2*i+1].set_ylabel('S/N')
#     plt.tight_layout()
#     plt.show()

# %%
# visualize spectrum
spectral_file = ps.io.files.make_full_path(proc_path,'1',indexinfo={'prefix':'spectra','nint':5,'suffix':'','extension':'.fits'})[0]
print(spectral_file)
order = 3

for i in ps.io.files.extract_filestring(orders,method='index'):
    plot_one_order(spectral_file,i)
# Out:
# /Users/adam/projects/spex_archive/test_uspex-SXD//proc/spectra00001.fits

# %% [markdown]
# ## USPEX prism

# %%
# initial imports and setup
import pyspextool as ps
import os

# what instrument and mode we are using
instrument = 'uspex'
mode = 'prism'

# point to test data folder for USPEX prism data
# NOTE: this should be moved internally
pfolder = os.path.dirname(os.path.abspath(ps.__file__))+'/../../'
tdfolder = pfolder+'/test_data/{}-{}/'.format(instrument,mode)

# set output pathways
redux_folder = '/Users/adam/projects/spex_archive/test_uspex-prism/'
raw_path = tdfolder
cal_path = redux_folder+'/cals/'
proc_path = redux_folder+'/proc/'
qa_path = redux_folder+'/cals/'

# file prefixes
src_prefix = 'sbd.2022B046.221019.spc.'
flat_prefix = 'sbd.2022B046.221019.flat.'
arc_prefix = 'sbd.2022B046.221019.arc.'

# file numbers
flat_files = '15-19'
arc_files = '20'
src_files = '1-2'
tell_files = '7-8'

# extraction details
orders = '1' # orders to extract
source_type = 'ps' # source type: 'ps' (default) or 'xs'
reduction_mode = 'A-B' # reduction mode: 'A-B' (default), 'A', 'A-Sky/Dark'
npos = 2
aperture_positions = [3.7, 11.2] # preset aperture positions
aperture_method = 'auto' # method to identify aperture: 'fixed', 'guess', or 'auto' (default)
ps_aperture = 1.5 # preset aperture width for point source in multiples of PSF radius
psf_radius = 1.5 # point source PSF radius
ps_bg_parameters = [2.5,4] # point source background parameters; radius to start, then width

# set up instrument
ps.pyspextool_setup(instrument,raw_path=raw_path, cal_path=cal_path, proc_path=proc_path, qa_path=qa_path,verbose=True)
# Out:
# Pyspextool Setup
# ----------------
# Instrument:  uspex
#
# Rawpath:  /Users/adam/python_codes/pyspextool/test_data/uspex-prism
# Calpath:  /Users/adam/projects/spex_archive/test_uspex-prism/cals
# Procpath:  /Users/adam/projects/spex_archive/test_uspex-prism/proc
# Qapath:  /Users/adam/projects/spex_archive/test_uspex-prism/cals
#
# QA Extension: .pdf

# %%
ps.extract.make_flat?

# %%
# conduct calibrations
#ps.extract.make_flat(flat_files,'flat{}'.format(flat_files),prefix=flat_prefix,qafile=True,verbose=True)

ps.extract.make_wavecal(arc_files,'flat{}.fits'.format(flat_files),'wavecal{}'.format(arc_files),\
    prefix=arc_prefix,qafile_findlines=True,use_stored_solution=False,verbose=True)
# Out:
# Make Wavecal File
# -----------------
# Loading FITS images...
# Extracting 1 apertures in 1 orders (without background subtraction)...
# 100% |**********************************************************************|
# Finding the lines...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Determining the wavelength solution...
# hi
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-5da7d41abde3> in <module>
#       2 #ps.extract.make_flat(flat_files,'flat{}'.format(flat_files),prefix=flat_prefix,qafile=True,verbose=True)
#       3
# ----> 4 ps.extract.make_wavecal(arc_files,'flat{}.fits'.format(flat_files),'wavecal{}'.format(arc_files),\
#       5     prefix=arc_prefix,qafile_findlines=True,use_stored_solution=False,verbose=True)
#
# ~/python_codes/pyspextool/src/pyspextool/extract/make_wavecal.py in make_wavecal(files, flat_file, output_name, prefix, suffix, extension, input_method, use_stored_solution, verbose, qafile_shift, qafile_findlines, qafile_fitlines, overwrite)
#      30     #
#      31
# ---> 32     instr.make_wavecal(files, flat_file, output_name, prefix=prefix,
#      33                        suffix=suffix, extension=extension,
#      34                        input_method=input_method,
#
# ~/python_codes/pyspextool/src/pyspextool/instrument_data/uspex_dir/uspex.py in make_wavecal(files, flat_file, output_name, prefix, suffix, extension, input_method, use_stored_solution, verbose, qafile_shift, qafile_findlines, qafile_fitlines, overwrite)
#     569         # Find the solution
#     570
# --> 571         solution = wavecal_solution_1d(wavecalinfo['orders'], lineinfo,
#     572                                        wavecalinfo['dispdeg'], xd=xd,
#     573                                        qafileinfo=qafileinfo,
#
# ~/python_codes/pyspextool/src/pyspextool/extract/wavecal_solution_1d.py in wavecal_solution_1d(orders, line_info, dispersion_degree, xd, verbose, qafileinfo)
#     210                                     qafileinfo['extension']))
#     211
# --> 212     solution = {'coeffs':fit['coeffs'], 'covar':fit['covar'], 'rms':fit['rms'],
#     213                 'nlines':ntot, 'ngood':ntot-nbad, 'nbad':nbad}
#     214
#
# KeyError: 'covar'

# %%
# extract first two images of science target

# load in images and apply flat and wavecal calbrations
ps.extract.load_image([src_prefix,ps.io.files.extract_filestring(src_files,method='index')[:2]],\
                      'flat{}.fits'.format(flat_files), 'wavecal{}.fits'.format(arc_files),\
                      flat_field=True, linearity_correction=True,reduction_mode=reduction_mode, \
                      qaplot=False, qafile=True, verbose=True)

# set extraction method to point source
ps.extract.set_extraction_type(source_type)

# make spatial profiles
ps.extract.make_spatial_profiles(qaplot=False, qafile=True, verbose=True)

# identify aperture positions (set above)
if aperture_method=='auto': # this works for method = 'auto'
    ps.extract.locate_aperture_positions(2, method=aperture_method, qaplot=False, qafile=True, verbose=True)
else:
    ps.extract.locate_aperture_positions(aperture_positions, method=aperture_method, qaplot=False, qafile=True, verbose=True)

# select orders to extract (set above)
ps.extract.select_orders(include=orders, qaplot=False, qafile=True, verbose=True)

# trace apertures
ps.extract.trace_apertures(qaplot=False, qafile=True, verbose=True)

# define the aperture - psf, width, background
ps.extract.define_aperture_parameters(ps_aperture, psf_radius=psf_radius,bg_radius=ps_bg_parameters[0],\
                        bg_width=ps_bg_parameters[1], qaplot=False, qafile=True) #, verbose=True

# extract away
ps.extract.extract_apertures(verbose=True)
# Out:
# Loading the flat...
# Loading the wavecal...
# Loading spc-00001.a.fits, spc-00002.b.fits and correcting for non-linearity...
# Flat fielding the image...
# Setting extraction type to point source...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (+, -)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00001.fits to disk.
# Wrote spectra00002.fits to disk.

# %%
# conduct extraction of all remaining files
# NOTE: this is redundant for the first two files

ps.extract.do_all_steps([src_prefix,src_files])
# Out:
# Loading spc-00001.a.fits, spc-00002.b.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (+, -)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00001.fits to disk.
# Wrote spectra00002.fits to disk.
#
# Loading spc-00003.b.fits, spc-00004.a.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (-, +)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00003.fits to disk.
# Wrote spectra00004.fits to disk.
#
# Loading spc-00005.a.fits, spc-00006.b.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (+, -)...
# Updating order selection...
# Tracing apertures...
#  29% |********************                                                  |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00005.fits to disk.
# Wrote spectra00006.fits to disk.
#
# Loading spc-00007.b.fits, spc-00008.a.fits and correcting for non-linearity...
# Flat fielding the image...
# Creating the spatial profiles...
# Locating the apertures...
# Aperture signs are (-, +)...
# Updating order selection...
# Tracing apertures...
#  14% |**********                                                            |
# /Users/adam/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 100% |**********************************************************************|
# Collecting plotting data for trace...
# 100% |**********************************************************************|
# Extracting 2 apertures in 7 orders (with background subtraction)...
# 100% |**********************************************************************|
# Wrote spectra00007.fits to disk.
# Wrote spectra00008.fits to disk.

# %%
# Checking output

# Temporary function to read in output spectraN.fits file
# data format is [# apertures x # orders, wave/flx/unc/back, column]
# returns wave, flux, unc, flags

import numpy
import matplotlib.pyplot as plt
from astropy.io import fits
# %matplotlib inline

def tmp_read_file(file,order,mode='A-B'):
    hdu = fits.open(file)
    data = hdu[0].data
    header = hdu[0].header # return this?
    hdu.close()
    orders = header['ORDERS'].split(',')
    orders = [int(x) for x in orders]
    if order > numpy.nanmax(orders) or order < numpy.nanmin(orders):
        raise ValueError('Input order {} is not in range of obtained orders {}'.format(order,orders))
    if mode=='A-B' or mode=='A':
        iref = orders.index(order)
        wave = data[iref,0,:]
        flux = data[iref,1,:]
        unc = data[iref,2,:]
        flags = data[iref,3,:]
    else:
        raise ValueError('cannot yet read in mode {}'.format(mode))
    return wave, flux, unc, flags

def plot_one_order(file,order,mode='A-B'):
    w,f,u,fl = tmp_read_file(file,order,mode=mode)
    fig = plt.figure(figsize=[12,4])
    ax1 = plt.subplot(121)
    ax1.plot(w,f)
    ax1.plot(w,u)
    ax1.set_ylim([-1.,1.2]*numpy.nanquantile(f,[0.05,0.95]))
    ax1.set_xlabel('Wavelength (micron)')
    ax1.set_ylabel('Integrated counts')
    ax2 = plt.subplot(122)
    ax2.plot(w,f/u)
    ax2.set_ylim([-1.,1.2]*numpy.nanquantile(f/u,[0.05,0.95]))
    ax2.set_xlabel('Wavelength (micron)')
    ax2.set_ylabel('S/N')
    plt.tight_layout()
    plt.show()

# def plot_all_orders(file,mode='A-B'):
#     hdu = fits.open(file)
#     data = hdu[0].data
#     header = hdu[0].header # return this?
#     hdu.close()
#     orders = header['ORDERS'].split(',')
#     orders = [int(x) for x in orders]
#     fig = plt.figure(figsize=[8,4*len(orders)])
#     ax = numpy.zeros(2*len(orders))
#     for i,ordr in enumerate(orders):
#         print(i)
#         w = data[i,0,:]
#         f = data[i,1,:]
#         u = data[i,2,:]
#         ax[2*i]= plt.subplot(2,int(len(orders)),int(2*i+1))
#         ax[2*i].plot(w,f)
#         ax[2*i].plot(w,u)
#         ax[2*i].set_ylim([-1.,1.2]*numpy.nanquantile(f,[0.05,0.95]))
#         ax[2*i].set_xlabel('Wavelength (micron)')
#         ax[2*i].set_ylabel('Integrated counts')
#         ax[2*i+1] = plt.subplot(2,int(len(orders)),int(2*i+2))
#         ax[2*i+1].plot(w,f/u)
#         ax[2*i+1].set_ylim([-1.,1.2]*numpy.nanquantile(f/u,[0.05,0.95]))
#         ax[2*i+1].set_xlabel('Wavelength (micron)')
#         ax[2*i+1].set_ylabel('S/N')
#     plt.tight_layout()
#     plt.show()

# %%
# visualize spectrum
spectral_file = ps.io.files.make_full_path(proc_path,'1',indexinfo={'prefix':'spectra','nint':5,'suffix':'','extension':'.fits'})[0]
print(spectral_file)
order = 3

for i in ps.io.files.extract_filestring(orders,method='index'):
    plot_one_order(spectral_file,i)
# Out:
# /Users/adam/projects/spex_archive/test_uspex-SXD//proc/spectra00001.fits
